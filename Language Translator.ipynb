# %%
#pip install translate

from translate import Translator
from googletrans import Translator
translator = Translator()
import pandas as pd
hindi_df = pd.read_excel('C:/Users/Amit Baghel/Desktop/Translater data.xlsx')

hindi_df['Gujrati'] = hindi_df['Hindi'].apply(translator.translate, src='hi', dest='gu').apply(getattr, args=('text',))
hindi_df['Bangali'] = hindi_df['Hindi'].apply(translator.translate, src='hi', dest='bn').apply(getattr, args=('text',))
hindi_df['Tamil'] = hindi_df['Hindi'].apply(translator.translate, src='hi', dest='ta').apply(getattr, args=('text',))
hindi_df['English'] = hindi_df['Hindi'].apply(translator.translate, src='hi', dest='en').apply(getattr, args=('text',))
hindi_df['Spanish'] = hindi_df['Hindi'].apply(translator.translate, src='hi', dest='es').apply(getattr, args=('text',))
hindi_df['French'] = hindi_df['Hindi'].apply(translator.translate, src='hi', dest='fr').apply(getattr, args=('text',))
hindi_df
# Out:
#                                                Hindi  \
# 0  अंदाजा 'ताकत' का लगाया जा सकता है, 'हौसलों' का...
# 1  वक़्त तो ज़रूर लगेगा तराशने में लेकिन चमक ज़ोर...
# 2  लक्ष्य सही होना चाहिए क्योंकि काम तो दीमक भी द...
# 3  सारी दुनिया कहती है हार मान लो लेकिन दिल धीरे ...
# 4  जीवन में हमेशा एक दूसरे को, समझने का प्रयत्न क...
#
#                                              Gujrati  \
# 0    ધારી 'શક્તિ' લાગુ કરી શકાય છે, 'સ્પિરિટ્સ' નહીં
# 1  કટ બનાવવા માટે સમય ચોક્કસપણે લેશે પરંતુ તેજ મજ...
# 2  ધ્યેય બરાબર હોવું જોઈએ કારણ કે દિમાગીઓ દિવસ-રા...
# 3  આખી દુનિયા કહે છે હાર મારો પણ હૃદય ધીમેથી કહે ...
# 4  જીવનમાં હંમેશાં એકબીજાને સમજવાનો પ્રયત્ન કરો, ...
#
#                                              Bangali  \
# 0  অনুমান 'শক্তি' প্রয়োগ করা যেতে পারে, 'আত্মার'...
# 1  কাটটি তৈরি করতে অবশ্যই সময় লাগবে তবে উজ্জ্বলত...
# 2  লক্ষ্যটি সঠিক হওয়া উচিত কারণ দারোয়ানরাও দিনর...
# 3  পুরো বিশ্ব বলে ছেড়ে দাও কিন্তু হৃদয় ধীরে ধীর...
# ...
